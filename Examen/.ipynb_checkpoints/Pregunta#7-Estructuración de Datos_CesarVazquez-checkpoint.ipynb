# %% [markdown]
# # Pregunta 7

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %%
df = pd.read_csv("output.csv")

# %%
df.head()
# Out:
#    Unnamed: 0 Fecha Accion        PEA  Anio Accion Periodo Accion    Pais  \
# 0           0     01/01/21  PEA 20-21         2021    Enero-Junio  México
# 1           1     01/01/21  PEA 20-21         2021    Enero-Junio  México
# 2           2     01/01/21  PEA 20-21         2021    Enero-Junio  México
# 3           3     01/01/21  PEA 20-21         2021    Enero-Junio  México
# 4           4     01/01/21  PEA 20-21         2021    Enero-Junio  México
#
#   Tipo de Accion           Accion     ID Evento Nombre Evento  ...  \
# 0    Targetizada  Ternium Contact  1.202101e+10       Evento   ...
# 1    Targetizada  Ternium Contact  1.202101e+10      Evento 4  ...
# 2    Targetizada  Ternium Contact  1.202101e+10      Evento 5  ...
# 3    Targetizada  Ternium Contact  1.202101e+10      Evento 0  ...
# 4    Targetizada  Ternium Contact  1.202101e+10      Evento 4  ...
#
#             DIGI-SC        Resto-Soft  Apto/ No Apto/ Destacado  \
# ...

# %% [markdown]
# #### Variables:
# - Destacado PyMetrics: Variable categórica del 0 - 3 en función a su desempeño en PyMetrics.
# - Actividad Grupal: Variable categórica en función a su desempeño en actividad grupal.
# - Apto AG: Variable catrgorica 0 u 1, en función a ser apto o no.
# - Inglés: Variable categórica (1-6) nivel de ingles del candidato.
# - Estatus academico: Variable categórica (0-2) en curso, no apto o indefinido.
# - Destacado: Variable categórica si es destacado, apto o no apto (0-2)
